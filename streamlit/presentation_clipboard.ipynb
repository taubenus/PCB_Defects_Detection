# %%
import h5py, os, cv2
#import streamlit as st
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import load_model
from sklearn.metrics import classification_report
from collections import Counter

# %%
image_path = os.path.abspath(os.path.join(os.getcwd(), 'data', 'Images'))

# %%
image_path
# Out:
# '/home/lucifa/Nextcloud/DataScientest/project/pcb/PCB_Defects_Detection/defense/data/Images'

# %%
choice = 'spur_'
img_pool_choice = [os.path.join(image_path, filename) for filename in os.listdir(image_path) if choice in filename]
rnd_3 = np.random.choice(range(20), 3, replace=False)
st.write(len(img_pool_choice))

fig = plt.figure()
for i,j in enumerate(rnd_3):
    img = cv2.imread(img_pool_choice[j])
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.sub
    plt.imshow(img)

# %%
img = cv2.imread('../data/Images_bb/bb-rotation_270_light_04_mouse_bite_16_1_600.jpg', )
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
pm = cv2.imread('../data/Pixel_masks/pm-rotation_270_light_04_mouse_bite_16_1_600.png')

# %%
plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(img)
plt.title('Original Image', fontsize=20)
plt.axis('off')
plt.subplot(122)
plt.imshow(pm)
plt.title('Pixel Mask', fontsize=20)
plt.axis('off');

# %%
img2 = cv2.imread('../data/Images_bb/bb-light_06_short_11_4_600.jpg', )
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img2)
#plt.axis('off')
plt.grid(visible=True, axis='both', color='w', linewidth=2)
plt.title('Cropping (600,600) image into 36x(100,100) images)', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Cropping (600,600) image into 36x(100,100) images\n(One defect is cut by the cropping)')
